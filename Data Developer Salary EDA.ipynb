# %% [markdown]
# # eda-project
#
# Use the "Run" button to execute the code.

# %% [markdown]
# # This project is about exploratory data analysis on Data Developers Salary 2024

# %% [markdown]
# ## Data preparation and cleaning

# %%
import pandas as pd

# %%
developers_salary_df = pd.read_csv('Dataset salary 2024.csv')

# %%
developers_salary_df
# Out:
#        work_year experience_level employment_type                  job_title  \
# 0           2024               SE              FT                AI Engineer
# 1           2024               SE              FT                AI Engineer
# 2           2024               SE              FT              Data Engineer
# 3           2024               SE              FT              Data Engineer
# 4           2024               SE              FT  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 16529       2020               SE              FT             Data Scientist
# 16530       2021               MI              FT   Principal Data Scientist
# 16531       2020               EN              FT             Data Scientist
# 16532       2020               EN              CT      Business Data Analyst
# 16533       2021               SE              FT       Data Science Manager
#
# ...

# %%
developers_salary_df.shape
# Out:
# (16534, 11)

# %%
developers_salary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16534 entries, 0 to 16533
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           16534 non-null  int64
#  1   experience_level    16534 non-null  object
#  2   employment_type     16534 non-null  object
#  3   job_title           16534 non-null  object
#  4   salary              16534 non-null  int64
#  5   salary_currency     16534 non-null  object
#  6   salary_in_usd       16534 non-null  int64
#  7   employee_residence  16534 non-null  object
#  8   remote_ratio        16534 non-null  int64
#  9   company_location    16534 non-null  object
#  10  company_size        16534 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.4+ MB

# %%
developers_salary_df.describe()
# Out:
#           work_year        salary  salary_in_usd  remote_ratio
# count  16534.000000  1.653400e+04   16534.000000  16534.000000
# mean    2023.226866  1.637270e+05  149686.777973     32.003750
# std        0.713558  3.402057e+05   68505.293156     46.245158
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2023.000000  1.017630e+05  101125.000000      0.000000
# 50%     2023.000000  1.422000e+05  141300.000000      0.000000
# 75%     2024.000000  1.872000e+05  185900.000000    100.000000
# max     2024.000000  3.040000e+07  800000.000000    100.000000

# %%
developers_salary_df[developers_salary_df.salary == developers_salary_df.salary_in_usd]
# Out:
#        work_year experience_level employment_type                  job_title  \
# 0           2024               SE              FT                AI Engineer
# 1           2024               SE              FT                AI Engineer
# 2           2024               SE              FT              Data Engineer
# 3           2024               SE              FT              Data Engineer
# 4           2024               SE              FT  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 16528       2021               SE              FT            Data Specialist
# 16529       2020               SE              FT             Data Scientist
# 16530       2021               MI              FT   Principal Data Scientist
# 16531       2020               EN              FT             Data Scientist
# 16532       2020               EN              CT      Business Data Analyst
#
# ...

# %%
developers_salary_df.salary_currency.unique()
# Out:
# array(['USD', 'GBP', 'CAD', 'EUR', 'DKK', 'INR', 'ILS', 'BRL', 'CHF',
#        'NZD', 'AUD', 'PLN', 'PHP', 'TRY', 'NOK', 'JPY', 'ZAR', 'HKD',
#        'SGD', 'THB', 'HUF', 'MXN', 'CLP'], dtype=object)

# %% [markdown]
# ## We don't need salary & salary_currency columns as much of the salaries are in usd so they are irrelevant

# %%
developers_salary_df.drop(columns=['salary_currency'], inplace = True)

# %%
developers_salary_df.drop(columns=['salary'], inplace=True)

# %%
developers_salary_df
# Out:
#        work_year experience_level employment_type                  job_title  \
# 0           2024               SE              FT                AI Engineer
# 1           2024               SE              FT                AI Engineer
# 2           2024               SE              FT              Data Engineer
# 3           2024               SE              FT              Data Engineer
# 4           2024               SE              FT  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 16529       2020               SE              FT             Data Scientist
# 16530       2021               MI              FT   Principal Data Scientist
# 16531       2020               EN              FT             Data Scientist
# 16532       2020               EN              CT      Business Data Analyst
# 16533       2021               SE              FT       Data Science Manager
#
# ...

# %%
developers_salary_df.company_location.unique()
# Out:
# array(['US', 'AU', 'GB', 'CA', 'NL', 'LT', 'DK', 'FR', 'ZA', 'NZ', 'AR',
#        'ES', 'KE', 'LV', 'IN', 'DE', 'IL', 'FI', 'AT', 'BR', 'CH', 'AE',
#        'PL', 'SA', 'UA', 'EG', 'PH', 'TR', 'OM', 'MX', 'PT', 'BA', 'IT',
#        'AS', 'IE', 'EE', 'MT', 'HU', 'LB', 'RO', 'VN', 'NG', 'LU', 'GI',
#        'CO', 'SI', 'GR', 'MU', 'RU', 'KR', 'CZ', 'QA', 'GH', 'SE', 'AD',
#        'EC', 'NO', 'JP', 'HK', 'CF', 'SG', 'TH', 'HR', 'AM', 'PK', 'IR',
#        'BS', 'PR', 'BE', 'ID', 'MY', 'HN', 'DZ', 'IQ', 'CN', 'CL', 'MD'],
#       dtype=object)

# %% [markdown]
# # Exploratory analysis questions and answers:
# Q: Find total data developers jobs around the world for each year from 2020 to 2024?

# %%
total_jobs_each_year_df = developers_salary_df.groupby('work_year').job_title.count()

# %%
total_jobs_each_year_df
# Out:
# work_year
# 2020      75
# 2021     218
# 2022    1655
# 2023    8519
# 2024    6067
# Name: job_title, dtype: int64

# %% [markdown]
# Q: Find 10 lowest salaries given to data developers?

# %%
lowest_salaries_df = developers_salary_df.sort_values('salary_in_usd', ascending=True).head(10)

# %%
lowest_salaries_df
# Out:
#        work_year experience_level employment_type  \
# 15639       2021               EN              FT
# 10800       2022               MI              FT
# 15936       2022               EN              FT
# 13011       2020               EX              FT
# 11061       2023               MI              FT
# 13814       2023               SE              FT
# 14416       2022               MI              FT
# 16366       2020               EN              PT
# 11650       2023               EN              FT
# 16432       2021               EN              FT
#
#                              job_title  salary_in_usd employee_residence  \
# 15639       Machine Learning Developer          15000                 TH
# 10800  Business Intelligence Developer          15000                 GH
# 15936                     Data Analyst          15000                 ID
# 13011               Staff Data Analyst          15000                 NG
# ...

# %% [markdown]
# Q: Find top 10 highest salaries given to data developers?

# %%
highest_salaries_df = developers_salary_df.sort_values('salary_in_usd', ascending=False).head(10)

# %%
highest_salaries_df
# Out:
#       work_year experience_level employment_type                   job_title  \
# 2804       2024               MI              FT                AI Architect
# 3647       2024               EN              FT                Data Analyst
# 7390       2023               MI              FT               Data Engineer
# 6412       2023               MI              FT   Machine Learning Engineer
# 7498       2023               SE              FT              Data Scientist
# 4622       2024               MI              FT  Machine Learning Scientist
# 4446       2024               SE              FT          Analytics Engineer
# 5033       2024               SE              FT                Data Analyst
# 6406       2023               MI              FT  Machine Learning Scientist
# 5808       2024               MI              FT  Machine Learning Scientist
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# ...

# %% [markdown]
# By finding the lowest and highest salaries we get to know that there aren't any outliers such as negative values which can be result of data entry errors, also we get to know that highest salaries are being paid in USA and by medium sized companies, however we will explore more about these later through visualization.

# %% [markdown]
# Q: Calculate average salaries of developers with respect to their job titles?

# %%
avg_salaries_df = developers_salary_df.groupby('job_title').salary_in_usd.mean().sort_values(ascending=False).head(15)

# %%
avg_salaries_df
# Out:
# job_title
# Analytics Engineering Manager     399880.000000
# Data Science Tech Lead            375000.000000
# Head of Machine Learning          299758.428571
# Managing Director Data Science    280000.000000
# AWS Data Architect                258000.000000
# AI Architect                      252551.241379
# Cloud Data Architect              250000.000000
# Director of Data Science          218775.333333
# Head of Data                      211860.196721
# Prompt Engineer                   205093.588235
# Data Infrastructure Engineer      204192.045455
# Robotics Software Engineer        196625.000000
# Data Analytics Lead               195536.739130
# Principal Data Scientist          194089.600000
# Data Science Manager              193961.319672
# Name: salary_in_usd, dtype: float64

# %% [markdown]
# Average salaries of data developers working in US companies

# %%
developers_salary_df[developers_salary_df.company_location == 'US'].salary_in_usd.mean()
# Out:
# 156904.4231299077

# %% [markdown]
# Q: Which job market is growing most in 2024 in field of data?

# %%
jobs_2024_df = developers_salary_df[developers_salary_df.work_year == 2024]

# %%
jobs_2024_df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2024               SE              FT                AI Engineer
# 1          2024               SE              FT                AI Engineer
# 2          2024               SE              FT              Data Engineer
# 3          2024               SE              FT              Data Engineer
# 4          2024               SE              FT  Machine Learning Engineer
# ...         ...              ...             ...                        ...
# 6073       2024               SE              FT               Data Analyst
# 6074       2024               SE              FT             Data Scientist
# 6075       2024               SE              FT             Data Scientist
# 6076       2024               SE              FT              Data Engineer
# 6077       2024               SE              FT              Data Engineer
#
# ...

# %%
jobs_count_2024 = jobs_2024_df.groupby('job_title').salary_in_usd.count()

# %%
jobs_count_2024.sort_values(ascending=False).head(1)
# Out:
# job_title
# Data Scientist    1138
# Name: salary_in_usd, dtype: int64

# %% [markdown]
# Data scientist is most growing job in 2024 around the world

# %% [markdown]
# ## Data Visualization

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
developers_salary_df.job_title.unique().shape
# Out:
# (155,)

# %%
plt.figure(figsize=(12,9))
sns.barplot(avg_salaries_df);
plt.xticks(rotation=75);
plt.title('Average salaries for top 15 highest earning job titles')
# Out:
# Text(0.5, 1.0, 'Average salaries for top 15 highest earning job titles')

# %%
plt.figure(figsize=(9,6))
plt.title('Distribution of salaries based on experience level')
sns.scatterplot(x=developers_salary_df.work_year, y=developers_salary_df.salary_in_usd, hue=developers_salary_df.experience_level);

# %%
large_company_df = developers_salary_df[developers_salary_df.company_size == 'L']
medium_company_df = developers_salary_df[developers_salary_df.company_size == 'M']
small_company_df = developers_salary_df[developers_salary_df.company_size == 'S']

# %%
plt.figure(figsize=(9,6))
plt.title('Salaries of developers according to company size')
plt.hist([large_company_df.salary_in_usd, medium_company_df.salary_in_usd, small_company_df.salary_in_usd], bins=6, stacked=True)
plt.legend(['Large', 'Medium', 'Small']);

# %%
plt.title('Total count of each type of employee in Data field')
sns.countplot(developers_salary_df.employment_type);

# %%
developers_salary_df[developers_salary_df.employment_type == 'PT'].shape
# Out:
# (38, 9)

# %%
developers_salary_df[developers_salary_df.employment_type == 'CT'].shape
# Out:
# (28, 9)

# %%
developers_salary_df[developers_salary_df.employment_type == 'FL'].shape
# Out:
# (14, 9)

# %% [markdown]
# This dataset mainly focuses on full time employees in Data field.

# %%
plt.title('Average salaries from 2020 to 2024')
sns.barplot(developers_salary_df, x=developers_salary_df.work_year, y=developers_salary_df.salary_in_usd);

# %% [markdown]
# ### The year 2020 has less confidence interval.

# %% [markdown]
# # Summary

# %% [markdown]
# ### By doing the exploratory data analysis on this dataset we find out many details such as that the job market for data developers has increased a lot from 2020 to 2024 and most growing field is Data science in 2024 so we can conclude that it has great scope ahead. Moreover, the highest paid job is of data analytics manager we have seen it by barplot visualization and it has highest avg salary than others. Also through data visualization we get to know that avg salaries have increased with the time, how there is not much difference between 2023 and 2024. Furthermore, we found out that huge market is in US and very high salaries are being paid there, in addition the highest salaries are being paid by medium-sized companies whereas large-size companies do not pay much high salaries. However, this dataset mainly focus on the senior level developers and full time employees so the salary data is mainly about them and so we cannot conclude something significant for junior, mild level or part time employees.
